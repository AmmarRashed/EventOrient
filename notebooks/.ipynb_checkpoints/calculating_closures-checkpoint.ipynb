# %%
import psycopg2

import pandas as pd
import numpy as np

from copy import deepcopy

import ast
import random
import networkx as nx
import time, unicodedata
import itertools

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

from joblib import Parallel, delayed
from datetime import datetime

# %%
twitter_users = pd.read_csv("../REST/static/filtered_twitter_users.csv",index_col="id")
twitter_users.sample(5)
# Out:
#               followers_count  friends_count  is_org lang      match_name  \
# id
# 2.232249e+09             66.0          172.0   False   en  ibrahim kurban
# 5.893993e+08             34.0           29.0   False   en     alper kodak
# 1.468747e+08            276.0          160.0   False   tr  halime karayel
# 6.664567e+07             79.0          161.0   False   tr    kutsal koruk
# 7.565966e+17             48.0          221.0   False   tr   sena gulseren
#
#               match_ratio            name    screen_name  truncated_id  \
# id
# 2.232249e+09         97.0  İbrahim Kurban      ikrbn6465     223224940
# 5.893993e+08        100.0     Alper Kodak    kodakalper1     589399262
# 1.468747e+08        100.0  Halime Karayel        Haluket     146874707
# 6.664567e+07        100.0    Kutsal Koruk    kutsalkoruk      66645671
# 7.565966e+17         96.0   Sena Gülseren  senagulseren_     756596649
#
#               community
# id
# 2.232249e+09          1
# 5.893993e+08          1
# 1.468747e+08          1
# 6.664567e+07          1
# 7.565966e+17          1

# %%
cons = pd.read_csv("../REST/static/filtered_twitter_connections.csv",index_col="id")
cons.sample(5, random_state=42)
# Out:
#             from_user_id          to_user_id             formation  first_date
# id
# 4445          4354816696           113954902  {'2018.05.24': True}        True
# 4118          3299537073           106086098  {'2018.05.08': True}        True
# 3893          2940722500  955847747093057537  {'2018.05.08': True}        True
# 4210          3407552944           334139315  {'2018.05.24': True}        True
# 5603  945405496466575360  847741204204634112  {'2018.05.08': True}        True

# %%
import ast
str2dict = lambda d : ast.literal_eval(d)
truncate = lambda x: int(str(int(x))[:9])

# %%
cons.formation = cons.formation.apply(str2dict)

# %%
def present_in_date(changes_dates, queried_date):
    """
    checking if a connection is present in a queried date
    changes_dates: {d1:True, d2:False, d3:True} connection added or removed
    queried_date: e.g. "2018.05.08"
    """
    str2date = lambda strdate: datetime.strptime(strdate, '%Y.%m.%d')  # 2018.05.08
    changes = sorted(changes_dates,key=lambda d: str2date(d))
    queried_date = datetime.strptime(queried_date, '%Y.%m.%d')
    present = False
    for d in changes:
        if queried_date < str2date(d):
            break
        present = changes_dates[d]
    return present

# %%
def get_dates(cons):
    all_dates = set()
    str2date = lambda strdate: datetime.strptime(strdate, '%Y.%m.%d')  # 2018.05.08

    for dates in cons.formation.apply(lambda x: list(x)):
        for date in dates:
            all_dates.add(str2date(date))
    return [d.strftime('%Y.%m.%d') for d in sorted(all_dates)]

# %%
dates = get_dates(cons)
d1 = dates[0]
d2 = dates[-1]

# %%
def get_connections_by_date(cons, date, present=True):
    nw = deepcopy(cons)
    for_col = nw.formation.apply(lambda dates: present_in_date(dates,date))
    return cons[for_col == present]

# %%
def calculate_new_edges(cons, d1, d2):
    return get_connections_by_date(get_connections_by_date(cons, d2), d1, False)

# %%
s = time.time()
new_edges = calculate_new_edges(cons, d1, d2)
print("took: ",time.time()-s)
# Out:
# took:  0.2541506290435791

# %%
twitter_users = pd.read_csv("../REST/static/filtered_twitter_users.csv", index_col="id")
twitter_users.sample(5)
# Out:
#                    match_name     screen_name  match_ratio             name  \
# id
# 1.289458e+09    suha demirsoy   suha_demirsoy           96    süha demirsoy
# 1.685805e+08    erkan akdemir    srkn_akdemir           96   serkan akdemir
# 9.442261e+08  sumeyra yerinde  sumeyrayerinde           97  Sümeyra Yerinde
# 3.341393e+08     beyza cengiz     Cengizbeyza          100     Beyza Cengiz
# 1.406830e+07       emrah kaya       emrahkaya          100       Emrah Kaya
#
#              lang  followers_count  friends_count  truncated_id  is_org
# id
# 1.289458e+09   tr             18.0           36.0     128945774   False
# 1.685805e+08   en             69.0          144.0     168580477   False
# 9.442261e+08   tr            110.0           94.0     944226110   False
# 3.341393e+08   tr            642.0          314.0     334139315   False
# 1.406830e+07   en          87334.0          438.0      14068305   False

# %% [markdown]
# ### Categorizing edges (user-user vs user-foci)

# %%
orgs_df = pd.read_csv("../REST/static/orgs.csv", index_col="id")
orgs_df.sample(5)
# Out:
#                             name      screen_name lang  \
# id
# 7.819232e+17    Şehir Gerçekleri  sehirgercekleri   tr
# 2.361548e+09                cefa      cefasehirfm   tr
# 2.847234e+09  Şehir Muzik Kulübü   sehirmusicclub   tr
# 8.057471e+17    In-House @ Şehir    inhouse_sehir   tr
# 5.330558e+08    Şehirli Aslanlar      uA_SehirUNI   tr
#
#                                                      match_name  match_ratio  \
# id
# 7.819232e+17   Şehir Üniversitesi (İnsan ve Toplum Bilimleri...         86.0
# 2.361548e+09                                       Dspace Admin         68.0
# 2.847234e+09   Şehir Üniversitesi (İnsan ve Toplum Bilimleri...         86.0
# 8.057471e+17   Şehir Üniversitesi (İnsan ve Toplum Bilimleri...         86.0
# 5.330558e+08                                      ! Sehir Sanat         69.0
#
#               followers_count  friends_count  truncated_id  is_org
# id
# 7.819232e+17              9.0          120.0     781923229    True
# 2.361548e+09            235.0          463.0     236154753    True
# 2.847234e+09            243.0          250.0     284723384    True
# 8.057471e+17             41.0            8.0     805747110    True
# 5.330558e+08           1672.0           61.0     533055810    True

# %%
orgs = set(orgs_df.index)

# %%
is_focal = lambda from_,to, orgs: (0,0) if (from_ in orgs and to in orgs)\
                                        or not(from_ in orgs or to in orgs)\
                                            else ((to,from_) if to in orgs else (from_,to))

# %%
new_edges["foci"] = new_edges.apply(lambda row:is_focal(row['from_user_id'], row['to_user_id'], orgs), axis=1)
new_edges["nonfoci"] = new_edges.foci.apply(lambda f: f[1])
new_edges["foci"] = new_edges.foci.apply(lambda f: f[0])
new_edges[new_edges.foci!=0].sample(5)
# Out:
#             from_user_id  to_user_id             formation  first_date  \
# id
# 69              47148388  1945992630  {'2018.05.24': True}        True
# 4388          4217413882   618131962  {'2018.05.24': True}        True
# 4242          3627550275  2612870692  {'2018.05.24': True}        True
# 5725  995255575398240256  1666891914  {'2018.05.24': True}        True
# 5120  831060584166719489   106086098  {'2018.05.24': True}        True
#
#             foci             nonfoci
# id
# 69    1945992630            47148388
# 4388  4217413882           618131962
# 4242  3627550275          2612870692
# 5725  1666891914  995255575398240256
# 5120   106086098  831060584166719489

# %% [markdown]
# # Calculating membership closures
# ### if a user u1 just got a new connection with foci f1 at time t2, get friends of u1 who had connections with f1 at time t1
# <img src="../misc/member.png">

# %%
t1 = get_connections_by_date(cons, d1)
t1["foci"] = t1.apply(lambda row:is_focal(row['from_user_id'], row['to_user_id'], orgs), axis=1)
t1["nonfoci"] = t1.foci.apply(lambda f: f[1])
t1["foci"] = t1.foci.apply(lambda f: f[0])
t1[t1.foci!=0].sample(5)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#       from_user_id  to_user_id             formation  first_date        foci  \
# id
# 1120     374146195  2940722500  {'2018.05.08': True}        True  2940722500
# 2516    1439588580   106086098  {'2018.05.08': True}        True   106086098
# 1711     589516467  4415560576  {'2018.05.08': True}        True  4415560576
# 4021    3093872810   174415744  {'2018.05.08': True}        True   174415744
# 2078     802893386   737056442  {'2018.05.08': True}        True   737056442
#
#          nonfoci
# id
# 1120   374146195
# 2516  1439588580
# 1711   589516467
# 4021  3093872810
# 2078   802893386

# %%
# foci'es present at t1 and t2
mutual_foci = new_edges[new_edges.foci!=0].merge(t1[t1.foci!=0], on="foci")
mutual_foci.sample(5)
# Out:
#           from_user_id_x  to_user_id_x           formation_x  first_date_x  \
# 4569  995255575398240256    1222491402  {'2018.05.24': True}          True
# 4596  995255575398240256    3064906390  {'2018.05.24': True}          True
# 3574  996760635730952194     106086098  {'2018.05.24': True}          True
# 4281  831060584166719489     609301446  {'2018.05.24': True}          True
# 4488  995255575398240256    1222491402  {'2018.05.24': True}          True
#
#             foci           nonfoci_x      from_user_id_y  to_user_id_y  \
# 4569  1222491402  995255575398240256          3234065324    1222491402
# 4596  3064906390  995255575398240256           153019444    3064906390
# 3574   106086098  996760635730952194           106086098     162310009
# 4281   609301446  831060584166719489  886280869991895041     609301446
# 4488  1222491402  995255575398240256           465062899    1222491402
#
#                formation_y  first_date_y           nonfoci_y
# 4569  {'2018.05.08': True}          True          3234065324
# 4596  {'2018.05.08': True}          True           153019444
# 3574  {'2018.05.08': True}          True           162310009
# 4281  {'2018.05.08': True}          True  886280869991895041
# 4488  {'2018.05.08': True}          True           465062899

# %% [markdown]
# ## check for membership closure

# %%
def membership_closure(cons, u1, u2):
    truncate = lambda x: int(str(int(x))[:9])
    u1_friends = set(
        cons.apply(lambda row: truncate(row['to_user_id'])if truncate(u1) == truncate(row['from_user_id'])\
                 else (truncate(row['from_user_id']) if truncate(u1) == truncate(row['to_user_id'])\
                   else np.NaN), axis=1).dropna())
    return u2 in u1_friends

# %%
start = time.time()
mutual_foci['membership_closure'] = mutual_foci.apply(lambda row: 
                                                      membership_closure(t1,
                                                                         row['nonfoci_x'],
                                                                         row['nonfoci_y']),axis=1)
print("Took:", time.time()-start)
print("There are", sum(mutual_foci["membership_closure"]), "membership_closures")
mutual_foci.sample(5)
# Out:
# Took: 395.7770209312439
# There are 0 membership_closures
#           from_user_id_x  to_user_id_x           formation_x  first_date_x  \
# 2702  932632343160020993     106086098  {'2018.05.24': True}          True
# 2674  932632343160020993     106086098  {'2018.05.24': True}          True
# 4478  995255575398240256    1222491402  {'2018.05.24': True}          True
# 4376  995255575398240256     737056442  {'2018.05.24': True}          True
# 2616  932632343160020993     106086098  {'2018.05.24': True}          True
#
#             foci           nonfoci_x  from_user_id_y  to_user_id_y  \
# 2702   106086098  932632343160020993      3298803633     106086098
# 2674   106086098  932632343160020993      2948587163     106086098
# 4478  1222491402  995255575398240256       342114048    1222491402
# 4376   737056442  995255575398240256       512080374     737056442
# 2616   106086098  932632343160020993      2336600952     106086098
#
#                formation_y  first_date_y   nonfoci_y  membership_closure
# 2702  {'2018.05.08': True}          True  3298803633               False
# 2674  {'2018.05.08': True}          True  2948587163               False
# 4478  {'2018.05.08': True}          True   342114048               False
# 4376  {'2018.05.08': True}          True   512080374               False
# 2616  {'2018.05.08': True}          True  2336600952               False

# %% [markdown]
# # Calculating focal closures
# ### if a user u1 just got a new connection with another user u2 at time t2, and u1 and u2 have been connected to foci f1 at time t1
# <img src="../misc/focal.png">

# %%
# Get all new user-user connections at t2
new_u2u_edges = new_edges[new_edges.foci==0]
new_u2u_edges.sample(5)
# Out:
#       from_user_id  to_user_id             formation  first_date  foci  \
# id
# 2416    1241036822   618131962  {'2018.05.24': True}        True     0
# 704      233548506   618131962  {'2018.05.24': True}        True     0
# 3632    2810110713   618131962  {'2018.05.24': True}        True     0
# 1054     353631855  3421922319  {'2018.05.24': True}        True     0
# 3093    2255825730  1537318436  {'2018.05.24': True}        True     0
#
#       nonfoci
# id
# 2416        0
# 704         0
# 3632        0
# 1054        0
# 3093        0

# %%
foci_t1 = t1[t1.foci!=0]
foci_t1.sample(5)
# Out:
#             from_user_id  to_user_id             formation  first_date  \
# id
# 226             90976741  2847233849  {'2018.05.08': True}        True
# 2304          1076267664  2940722500  {'2018.05.08': True}        True
# 1090           365164239  2940722500  {'2018.05.08': True}        True
# 1214           411064560  4091594428  {'2018.05.08': True}        True
# 4830  783600969393303556  2940722500  {'2018.05.08': True}        True
#
#             foci             nonfoci
# id
# 226   2847233849            90976741
# 2304  2940722500          1076267664
# 1090  2940722500           365164239
# 1214  4091594428           411064560
# 4830  2940722500  783600969393303556

# %%
users_with_mut_foci = foci_t1.groupby("foci")['nonfoci'].apply(lambda x: set(x)).reset_index()
users_with_mut_foci = users_with_mut_foci[users_with_mut_foci.nonfoci.apply(lambda x: len(x)>1)]
users_with_mut_foci.sample(5)
# Out:
#           foci                                            nonfoci
# 18  2529427087  {2866935552, 709465725648424960, 7688711934704...
# 8    737056442  {764021907171663872, 798186610583928833, 79882...
# 3    443551180  {723926465679646720, 745389817765203968, 76023...
# 15  2207630876  {342114048, 916911351632711680, 70946572564842...
# 24  3892757176  {989792178183471104, 704764994857078784, 70946...

# %%
def is_fclosure(f, t, users_with_mut_foci):
    for _, focal in users_with_mut_foci.iterrows():
        if f in focal["nonfoci"] and t in focal["nonfoci"]:
            return True
    return False

# %%
new_u2u_edges.sample(5)
# Out:
#             from_user_id  to_user_id             formation  first_date  foci  \
# id
# 20              32660008   253616057  {'2018.05.24': True}        True     0
# 3               14668733  1537318436  {'2018.05.24': True}        True     0
# 3902          2966940226   113954902  {'2018.05.24': True}        True     0
# 5497  907489214643818496   618131962  {'2018.05.24': True}        True     0
# 4999  800742744838709248   162310009  {'2018.05.24': True}        True     0
#
#       nonfoci
# id
# 20          0
# 3           0
# 3902        0
# 5497        0
# 4999        0

# %%
start = time.time()
new_u2u_edges["is_focal_closure"] = new_u2u_edges.apply(
    lambda row: is_fclosure(
        row["from_user_id"], row["to_user_id"], users_with_mut_foci), axis=1)
print("took:", time.time()-start)
print("There are",sum(new_u2u_edges["is_focal_closure"]), "focal closures")
new_u2u_edges.sample(5)
# Out:
# took: 0.5408101081848145
# There are 638 focal closures
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#       from_user_id  to_user_id             formation  first_date  foci  \
# id
# 4125    3311816145    32660008  {'2018.05.24': True}        True     0
# 2627    1537318436  1439588580  {'2018.05.24': True}        True     0
# 2635    1537318436  2301123770  {'2018.05.24': True}        True     0
# 4435    4306171395   618131962  {'2018.05.24': True}        True     0
# 24        32660008   791665500  {'2018.05.24': True}        True     0
#
#       nonfoci  is_focal_closure
# id
# 4125        0              True
# 2627        0              True
# 2635        0              True
# 4435        0             False
# 24          0              True
